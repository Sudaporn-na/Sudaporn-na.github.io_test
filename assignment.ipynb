# %%
# ติดตั้ง pandas ถ้าจำเป็น (รันครั้งแรกเท่านั้น)
# !pip install pandas

# นำเข้าไลบรารี
import pandas as pd

# อ่านไฟล์ CSV
df = pd.read_csv('data.csv')

# แสดงข้อมูล
print("แสดง DataFrame ทั้งหมด:")
display(df) # ใช้ display(df) ใน Jupyter Notebooks เพื่อแสดงตารางที่สวยงามกว่า print(df)
# Out:
# แสดง DataFrame ทั้งหมด:
#      ชื่อ  อายุ      เมือง
# 0   สมชาย    30   กรุงเทพฯ
# 1  สมหญิง    25  เชียงใหม่
# 2    อดัม    40     ภูเก็ต
